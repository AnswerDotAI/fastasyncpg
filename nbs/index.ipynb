# %%
#| hide
from fastasyncpg.core import *

# %% [markdown]
# # fastasyncpg
#
# > A simple wrapper for asyncpg

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install fastasyncpg in Development mode

# %% [markdown]
# ```sh
# # make sure fastasyncpg package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to fastasyncpg
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/AnswerDotAI/fastasyncpg.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c AnswerDotAI fastasyncpg
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install fastasyncpg
# ```
#
#
# [repo]: https://github.com/AnswerDotAI/fastasyncpg
# [docs]: https://AnswerDotAI.github.io/fastasyncpg/
# [pypi]: https://pypi.org/project/fastasyncpg/
# [conda]: https://anaconda.org/AnswerDotAI/fastasyncpg

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/AnswerDotAI/fastasyncpg
# [docs]: https://AnswerDotAI.github.io/fastasyncpg/
# [pypi]: https://pypi.org/project/fastasyncpg/
# [conda]: https://anaconda.org/AnswerDotAI/fastasyncpg

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
